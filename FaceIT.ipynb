# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
 cd "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras"
# Out:
# /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras

# %%
# !wget http://masc.cs.gmu.edu/wiki/uploads/partialconv/mask.zip
# !unzip -q mask.zip
# Out:
# --2020-02-12 18:45:58--  http://masc.cs.gmu.edu/wiki/uploads/partialconv/mask.zip
# Resolving masc.cs.gmu.edu (masc.cs.gmu.edu)... 129.174.125.37
# Connecting to masc.cs.gmu.edu (masc.cs.gmu.edu)|129.174.125.37|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45168987 (43M) [application/zip]
# Saving to: ‘mask.zip’
#
# mask.zip            100%[===================>]  43.08M  12.0MB/s    in 6.0s
#
# 2020-02-12 18:46:05 (7.17 MB/s) - ‘mask.zip’ saved [45168987/45168987]

# %%
# !pip install -r requirements/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 317kB 4.9MB/s
# ...
#      |████████████████████████████████| 12.9MB 45.8MB/s
# ...
#      |████████████████████████████████| 2.8MB 39.3MB/s
# ...
#      |████████████████████████████████| 2.1MB 48.8MB/s
# ...
#      |████████████████████████████████| 25.0MB 1.3MB/s
# ...
#      |████████████████████████████████| 51kB 7.6MB/s
# ...
#      |████████████████████████████████| 25.3MB 30.9MB/s
# ...
# ERROR: plotnine 0.6.0 has requirement matplotlib>=3.1.1, but you'll have matplotlib 3.0.2 which is incompatible.
# ERROR: mizani 0.6.0 has requirement matplotlib>=3.1.1, but you'll have matplotlib 3.0.2 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: h5py 2.8.0
#     Uninstalling h5py-2.8.0:
#       Successfully uninstalled h5py-2.8.0
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2020-02-13 17:58:51--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.22.117.137, 34.225.254.242, 35.169.40.78, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.22.117.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.1’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  33.8MB/s    in 0.4s
#
# 2020-02-13 17:58:51 (33.8 MB/s) - ‘ngrok-stable-linux-amd64.zip.1’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok

# %%
LOG_DIR = './outputs'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://c6348bba.ngrok.io

# %%
# !mkdir config
# !cp config/main_config.ini config
# Out:
# mkdir: cannot create directory ‘config’: File exists
# cp: 'config/main_config.ini' and 'config/main_config.ini' are the same file

# %%
# %%writefile config/main_config.ini
# [TRAINING]
# WGAN_TRAINING_RATIO = 1
# NUM_EPOCHS = 5
# BATCH_SIZE = 4
# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# NUM_CHANNELS = 3
# LEARNING_RATE = 0.002
# SAVE_MODEL_STEPS_PERIOD = 500
#
# [MODEL]
# ADD_MASK_AS_GENERATOR_INPUT = True
# GRADIENT_PENALTY_LOSS_WEIGHT = 10
# ID_MRF_LOSS_WEIGHT = 0.05
# ADVERSARIAL_LOSS_WEIGHT = 0.001
# NN_STRETCH_SIGMA = 0.5
# VGG_16_LAYERS = 3,6,10
# ID_MRF_STYLE_WEIGHT = 1.0
# ID_MRF_CONTENT_WEIGHT = 1.0
# NUM_GAUSSIAN_STEPS = 3
# GAUSSIAN_KERNEL_SIZE = 32
# GAUSSIAN_KERNEL_STD = 40.0
# Out:
# Overwriting config/main_config.ini

# %%
# !ls
# Out:
# colab		    layers    ngrok-stable-linux-amd64.zip    requirements
# config		    LICENSE   ngrok-stable-linux-amd64.zip.1  runner.py
# custom_test	    mask      outputs.zip		      samples
# custom_test_output  mask.zip  pics			      tests
# data_generators     models    predict.py		      utils
# images_data	    ngrok     README.md

# %%
# !python runner.py --train_path "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/images_data" --mask_path "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/mask" --experiment_name "gmcnn256x256" -warm_up_generator
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:54: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Setting visible GPU to 0
# INFO:tensorflow:Performing generator training only with the reconstruction loss.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %%
# %%writefile config/main_config.ini
# [TRAINING]
# WGAN_TRAINING_RATIO = 5
# NUM_EPOCHS = 5
# BATCH_SIZE = 4
# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# NUM_CHANNELS = 3
# LEARNING_RATE = 0.0002
# SAVE_MODEL_STEPS_PERIOD = 1000
#
# [MODEL]
# ADD_MASK_AS_GENERATOR_INPUT = True
# GRADIENT_PENALTY_LOSS_WEIGHT = 10
# ID_MRF_LOSS_WEIGHT = 0.05
# ADVERSARIAL_LOSS_WEIGHT = 0.0005
# NN_STRETCH_SIGMA = 0.5
# VGG_16_LAYERS = 3,6,10
# ID_MRF_STYLE_WEIGHT = 1.0
# ID_MRF_CONTENT_WEIGHT = 1.0
# NUM_GAUSSIAN_STEPS = 3
# GAUSSIAN_KERNEL_SIZE = 32
# GAUSSIAN_KERNEL_STD = 40.0
# Out:
# Overwriting config/main_config.ini

# %%
# !python runner.py --train_path "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/images_data" --mask_path "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/mask" -from_weights --experiment_name "gmcnn256x256"
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:54: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Setting visible GPU to 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %%
from IPython.display import Image

# %%
# !ls outputs/gmcnn256x256/predicted_pics/wgan/
# Out:
# step_000.png  step_150.png  step_300.png  step_450.png
# step_050.png  step_200.png  step_350.png  step_500.png
# step_100.png  step_250.png  step_400.png

# %%
Image('outputs/gmcnn256x256/predicted_pics/wgan/step_300.png')

# %%
# !zip -r outputs.zip outputs
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/gmcnn256x256/ (stored 0%)
#   adding: outputs/gmcnn256x256/summaries/ (stored 0%)
#   adding: outputs/gmcnn256x256/summaries/local_discriminator.txt (deflated 88%)
#   adding: outputs/gmcnn256x256/summaries/global_discriminator.txt (deflated 84%)
#   adding: outputs/gmcnn256x256/summaries/generator.txt (deflated 93%)
#   adding: outputs/gmcnn256x256/logs/ (stored 0%)
#   adding: outputs/gmcnn256x256/logs/warm_up_generator/ (stored 0%)
#   adding: outputs/gmcnn256x256/logs/warm_up_generator/events.out.tfevents.1581569547.63a3c810c7f9 (deflated 86%)
#   adding: outputs/gmcnn256x256/logs/warm_up_generator/events.out.tfevents.1581569008.f9b634fcaabc (deflated 86%)
#   adding: outputs/gmcnn256x256/logs/warm_up_generator/events.out.tfevents.1581570307.63a3c810c7f9 (deflated 84%)
#   adding: outputs/gmcnn256x256/logs/wgan/ (stored 0%)
#   adding: outputs/gmcnn256x256/logs/wgan/events.out.tfevents.1581578216.63a3c810c7f9 (deflated 84%)
# ...

# %%
# !rm -rf outputs/

# %%
# !python runner.py --train_path images --mask_path mask -warm_up_generator -from_weights
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# usage: runner.py [-h] --train_path TRAIN_PATH --mask_path MASK_PATH
#                  --experiment_name EXPERIMENT_NAME [-warm_up_generator]
#                  [-from_weights] [--gpu GPU]
# runner.py: error: the following arguments are required: --experiment_name

# %%
# !python predict.py --image "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/custom_test" --mask "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/mask" --save_to "/content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/custom_test_output"
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/gmcnn/inpainting-gmcnn-keras/utils/training_utils.py:49: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# Traceback (most recent call last):
#   File "predict.py", line 91, in <module>
#     main()
#   File "predict.py", line 62, in main
#     config=config)
# TypeError: __init__() missing 1 required positional argument: 'output_paths'
